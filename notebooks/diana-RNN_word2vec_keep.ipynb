# %% [markdown]
# # GloVe & CNN

# %% [markdown]
# GLOVE fonctionne de la même manière que Word2Vec. Alors que vous pouvez voir ci-dessus que Word2Vec est un modèle «prédictif» qui prédit un mot donné par le contexte, GLOVE apprend en construisant une matrice de cooccurrence (mots X contexte) qui compte essentiellement la fréquence d'apparition d'un mot dans un contexte. Comme il s'agira d'une matrice gigantesque, nous factorisons cette matrice pour obtenir une représentation de dimension inférieure. Il y a beaucoup de détails dans GLOVE mais c'est l'idée approximative.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Flatten, Embedding, Activation, Dropout, Masking
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.model_selection import train_test_split

import numpy as np
from numpy import array
import pandas as pd

from NLP_Natural_Disasters.data import get_data, clean_data

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Preprocessing

# %%
train_df = get_data()
X_train = clean_data(train_df)

y_train = X_train['target']

X_train_text = X_train['text']
X_train_text.tail()
# Out:
# 7608                                                                two giant crane holding bridge collapse nearby home
# 7609                             ariaahrary thetawniest control wild fire california even northern part state troubling
# 7610                                                                                               utckm volcano hawaii
# 7611    police investigating ebike collided car little portugal ebike rider suffered serious nonlife threatening injury
# 7612                                                            latest home razed northern california wildfire abc news
# Name: text, dtype: object

# %% [markdown]
# ###  👉 Set id column appart, that will be join after in the output of prediction

# %%
X_train_id = X_train['id']

# %%
X_train['target'].value_counts()
# Out:
# 0    4342
# 1    3271
# Name: target, dtype: int64

# %% [markdown]
# ## 😲 Apply changes to test.csv

# %%
X_test = pd.read_csv('/home/dianavo/code/AxelCatelan/NLP_Natural_Disasters/raw_data/test.csv')
X_test = clean_data(X_test)
X_test.tail()
# Out:
#          id  \
# 3258  10861
# 3259  10865
# 3260  10868
# 3261  10874
# 3262  10875
#
#                                                                                                             text
# 3258                                                      earthquake safety los angeles ûò safety fastener xrwn
# 3259  storm ri worse last hurricane cityampothers hardest hit yard look like bombed around k still without power
# 3260                                                                               green line derailment chicago
# 3261                                                                     meg issue hazardous weather outlook hwo
# 3262                                                   cityofcalgary activated municipal emergency plan yycstorm

# %% [markdown]
# > New clean_data() version :
# Enleve les mots qui apparaissent qu'une fois |
# Enleve les Twitter handles |
# Transforme les accent, etc. en characters ascii |
# Drop les lignes vides

# %% [markdown]
# ### Data Cleaning to add eventually : done

# %% [markdown]
# Pour éviter les mots rares qui n'apparaissent qu'une fois type mot avec faute, contraction etc

# %%
#def transform_to_list_word(serie):
#    split_list=[]  
#    for sentence in serie.str.split():
#        for word in sentence:
#            split_list.append(word)
#    return split_list

# %%
#list_word = transform_to_list_word(cleaned_df['text'])
#len(list_word)

# %% [markdown]
# **POUR DATA CLEANING**

# %%
# twitts = ' '.join(cleaned_df['text'])
# twitts = twitts.split()
# freq_comm = pd.Series(twitts).value_counts()
# rare = freq_comm[freq_comm.values == 1]
# rare

# %%
#list_word_new = [word for word in list_word if word not in rare]
#len(list_word_new)

# %%
#cleaned_df

# %% [markdown]
# **POUR DATA CLEANING**

# %%
# %%time
# def get_clean_text(sentence):
#     """ split """
#     if type(sentence) is str:
#         sentence = " " .join(word for word in sentence.split() if word not in rare)
#         return sentence

# cleaned_df['tweet'] = cleaned_df['text'].apply(lambda x: get_clean_text(x))

# %%
# phrase = 'i love chocolate'
# phrase.split()

# %%
# token = Tokenizer()
# token.fit_on_texts(phrase)

# %%
# encoded_text = token.texts_to_sequences(phrase)
# encoded_text

# %% [markdown]
# ### Token

# %%
# modify cleaned_df['text'] -> ['tweet']
text = X_train_text.tolist()
text
# Out:
# ['deed reason earthquake may allah forgive u',
#  'forest fire near la ronge sask canada',
#  'resident asked shelter place notified officer evacuation shelter place order expected',
#  'people receive wildfire evacuation order california',
#  'got sent photo ruby alaska smoke wildfire pours school',
#  'rockyfire update california hwy closed direction due lake county fire cafire wildfire',
#  'flood disaster heavy rain cause flash flooding street manitou colorado spring area',
#  'im top hill see fire wood',
#  'there emergency evacuation happening building across street',
#  'im afraid tornado coming area',
#  'three people died heat wave far',
#  'haha south tampa getting flooded hah wait second live south tampa gon na gon na fvck flooding',
#  'raining flooding florida tampabay tampa day ive lost count',
#  'flood bago myanmar arrived bago',
#  'damage school bus multi car crash breaking',
#  'whats man',
#  'love fruit',
#  'summer lovely',
#  'car fast',
#  '',
#  'ridiculous',
#  'london cool',
#  'love skiing',
#  'wonderful day',
#  '',
#  'wayi cant eat shit',
#  'nyc last week',
#  'love girlfriend',
#  '',
#  'like pasta',
#  'end',
#  'bbcmtd wholesale market ablaze',
#  'always try bring heavy metal rt',
#  'africanbaze breaking newsnigeria flag set ablaze aba',
#  'cry set ablaze',
#  'plus side look sky last night ablaze',
#  'phdsquares mufc theyve built much hype around new acquisition doubt set epl ablaze season',
#  'inec office abia set ablaze',
#  'barbados bridgetown jamaica \x89ûò two car set ablaze santa cruz \x89ûó head st elizabeth police superintende',
#  'ablaze lord',
#  'check nsfw',
#  'outside youre ablaze alive youre dead inside',
#  'awesome time visiting cfc head office ancop site ablaze thanks tita vida taking care u',
#  'pumped ablaze southridgelife',
#  'wanted set chicago ablaze preaching hotel',
#  'gained follower last week know stats grow',
#  'west burned thousand wildfire ablaze california alone',
#  'building perfect tracklist life leave street ablaze',
#  'check nsfw',
#  'first night retainer quite weird better get used wear every single night next year least',
#  'deputy man shot brighton home set ablaze',
#  'man wife get six year jail setting ablaze niece',
#  'santa cruz \x89ûó head st elizabeth police superintendent lanford salmon r',
#  'police arsonist deliberately set black church north carolinaåêablaze',
#  'noches elbestia alexissanchez happy see teammate training hard goodnight gunner',
#  'kurd trampling turkmen flag later set ablaze others vandalized office turkmen front diyala',
#  'truck ablaze r voortrekker ave outside tambo intl cargo section',
#  'set heart ablaze every city gift every skyline like kiss upon lip \x89û',
#  'sky ablaze tonight los angeles im expecting ig fb filled sunset shot know peep',
#  'west burned thousand wildfire ablaze california alone climate energy',
#  'revel wmv video mean mac farewell ablaze wmv en route dvd gtxrwm',
#  'progressive greeting month student would set pen ablaze torch publication',
#  'rene ablaze amp jacinta secret k fallen sky edit mar',
#  'navista steve fire something else california tinderbox clown setting hood ablaze news',
#  'nowplaying rene ablaze amp ian buff magnitude edm',
#  'nxwestmidlands huge fire wholesale market ablaze',
#  'ablaze time talk go dont know make due work',
#  'cant kid cuz got bicycle accident amp split testicle impossible kid michael father',
#  'accident w nashvilletraffic traffic moving slower usual',
#  'accident center lane blocked santaclara u nb great america pkwy bayarea traffic',
#  'personalinjury accident summer read advice amp see solicitor help otleyhour',
#  'stlouis caraccidentlawyer speeding among top cause teen accident car accident tee\x89û',
#  'reported motor vehicle accident curry herman rd near stephenson involving overturned vehicle please use',
#  'bigrigradio live accident awareness',
#  'mile marker south mooresville iredell vehicle accident ramp closed pm',
#  'rt sleepjunkies sleeping pill double risk car accident',
#  'accident knew gon happen',
#  'traffic accident n cabrillo hwymagellan av mir',
#  'mile marker south mooresville iredell vehicle accident congestion pm',
#  'pastor scene accidentwho owner range rover',
#  'mom didnt get home fast wished mom accident truck spilt mayonnaise',
#  'horrible car accident past sunday im finally able get around thank god',
#  'wait see pissed donnie tell another accident',
#  'truckcrash overturn fortworth interstate click youve crashgt',
#  'accident ashville u sb sr traffic',
#  'carolina accident motorcyclist dy crash car crossed median motorcycle rider traveling',
#  'fyi cadfyi accident property damagenhs piner rdhorndale dr',
#  'rt naayf first accident year turning onto chandanee magu near mma taxi rammed halfway turned everyone conf\x89û',
#  'accident left lane blocked manchester rt nb eddy rd stop go traffic back nha delay min traffic',
#  'accident property damage piner rdhorndale dr',
#  'accident',
#  'fyi cadfyi accident property damagewpd th st',
#  'pm traffic accident injury willis foreman rd',
#  'aashiqui actress anu aggarwal nearfatal accident',
#  'suffield alberta accident',
#  'mile backup southaccident blocking right lane exit langtree rdconsider nc nc nc alternate',
#  'accident changed life help determine option financially support life care plan ongoing treatment',
#  'breaking deadly motorcycle car accident happened hagerstown today ill detail yourstate whag',
#  'flowri marinading accident',
#  'car even week got fucking car accident mf cant fucking drive',
#  'norwaymfa bahrain police previously died road accident killed explosion',
#  'still heard church leader kenya coming forward comment accident issue disciplinary measuresarrestpastornganga',
#  'aftershockdelo scuf p live game cya',
#  'man drive effort get painful man win roger bannister',
#  'ir icemoon aftershock djicemoon dubstep trapmusic dnb edm dance ices\x89û',
#  'victory bargain basement price dwight david eisenhower',
#  'ir icemoon aftershock djicemoon dubstep trapmusic dnb edm dance ices\x89û',
#  'nobody remembers came second charles schulz',
#  'aftershockdelo im speaking someone using scuf xb people end getting p also',
#  'harder conflict glorious triumph thomas paine',
#  'growingupspoiled going clay pigeon shooting cry aftershock',
#  'guess one actually want free aftershock tc',
#  'aftershock terrifying best roller coaster ive ever disclaimer ive',
#  'aftershock',
#  'ir icemoon aftershock djicemoon dubstep trapmusic dnb edm dance ices\x89û',
#  'ir icemoon aftershock djicemoon dubstep trapmusic dnb edm dance ices\x89û',
#  'ir icemoon aftershock djicemoon dubstep trapmusic dnb edm dance ices\x89û',
#  'kjfordays im seeing issue aftershock',
#  'ir icemoon aftershock djicemoon dubstep trapmusic dnb edm dance ices\x89û',
#  'ir icemoon aftershock djicemoon dubstep trapmusic dnb edm dance ices\x89û',
#  'wisdomwed bonus minute daily habit could really improve life many already lifehacks',
#  'aftershock protect profit next global financial meltdown david wiedemer http',
#  'moment get scary roller coaster guy behind screaming bloody murder silverwood aftershock',
#  'aftershock \x89ã¢ full\x89ã¢ streaming youtube',
#  'gtgt aftershock protect profit next global financial book esquireattire',
#  'sometimes face difficulty youre something wrong youre something right joel osteen',
#  'thing stand dream try belief actually possible joel brown',
#  'praise god ministry tell like wdyouth biblestudy',
#  'remembering going die best way know avoid trap thinking something lose \x89ûò steve job',
#  'tried orange aftershock today life never',
#  'onfireanders love bb',
#  'aftershock',
#  'aftershock back school kick great want thank everyone making possible great night',
#  'people say done interrupt \x89ûò george bernard shaw',
#  'first man get oyster second man get shell andrew carnegie',
#  'anyone need pu tonight play hybrid slayer p eu hmu codsandscrims empirikgaming codawscrims tpkotc tpfa aftershockorg',
#  'expert france begin examining airplane debris found reunion island french air accident expert news',
#  'strict liability context airplane accident pilot error common component aviation cr',
#  'crobscarla lifetime odds dying airplane accident',
#  'expert france begin examining airplane debris found reunion island french air accident expert wedn',
#  'alexalltimelow theyre airplane accident theyre gon na die cuties good job',
#  'family member osama bin laden died airplane accident ironic gov shit suspect',
#  'man go airplane engine accident via youtube',
#  'horrible accident man died wing airplane',
#  'cessna airplane accident ocampo coahuila mexico july killed four men including state coahuila government official',
#  'horrible accident man died wing airplane watchthevideo',
#  'expert france begin examining airplane debris found reunion island french air accident expert wednesday\x89û',
#  'expert france begin examining airplane debris found reunion island french air accident expert wednesday began examining',
#  'kca votejktid mbataweel rip binladen family member killed airplane accident',
#  'almost sent coworker nude accident thank god airplane mode',
#  'mickinyman theatlantic might killed airplane accident night car wreck politics best',
#  'expert france begin examining airplane debris found reunion island french air accident expert mlb',
#  'unbelievably insane man airport airplane aircraft aeroplane runway accident freaky\x89û',
#  'horrible accident man died wing airplaneåê',
#  'horrible accident man died wing airplane',
#  'usama bin ladin family dead airplane crash naturally accident',
#  'pilot dy plane crash car festival via youtube crash aircraft airplane pilot death accident carfest',
#  'strict liability context airplane accident',
#  'dtn brazil expert france begin examining airplane debris found reunion island french air accident exp',
#  'expert france begin examining airplane debris found reunion island french air accident expert wedn',
#  'horrible accident man died wing \x89ûïairplane\x89û\x9d wtf can\x89ûªt believe eye \x89ûò',
#  'nicole fletcher one victim crashed airplane time ago accident left little bit trauma although shes',
#  'omg horrible accident man died wing airplane',
#  'omg dont believe rip bro airplane accident jetengine turbojet boing g',
#  'expert france begin examining airplane debris found reunion island french air accident expert wednesday began examining',
#  'airplane accident',
#  'phone look like car ship airplane accident terrible',
#  'statistically im risk getting killed cop dying airplane accident',
#  'airplane crash house colombia people die accident',
#  'shooting airplane accident',
#  'could drone cause airplane accident pilot worried use drone esp close vicinity airport',
#  'early wake call sister begging come amp ride wher ambulance hospital rodkiai',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'two air ambulance scene serious crash two car lorry emsne\x89û',
#  'twelve feared killed pakistani air ambulance helicopter crash reuters yugvani',
#  'leading emergency service bos welcome new ambulance charity',
#  'anyone travelling aberystwythshrewsbury right there incident service halt outside shrew ambulance scene',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'ambulance sprinter automatic frontline vehicle choice lez compliant ebay',
#  'new nanotech device able target destroy blood clot',
#  'skyhawkmm traplord fredosantana lilreese hella crazy fight ambulance couple mosh pit',
#  'get run ambulance lucky justsaying randomthought',
#  'news twelve feared killed pakistani air ambulance helicopter crash tilnow dna',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'tanslash waiting ambulance',
#  'fouseytube ok need ambulance hahahah good',
#  'ambulance sprinter automatic frontline vehicle choice lez compliant ebay',
#  'pakistan air ambulance helicopter crash kill nine',
#  'thenissonian rejectdcartoons nissan ok need medical assistance call ambulance need',
#  'em ny emts petition per hour \x89û÷minimum wage\x89ûª em paramedic ambulance',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'ambulance sprinter automatic frontline vehicle choice lez compliant ebay',
#  'ambulance sprinter automatic frontline vehicle choice lez compliant ebay',
#  'kiwikaryn check whats parking lot said last year ambulance st john',
#  'dont know way ambulance coming ltlt',
#  'reuters twelve feared killed pakistani air ambulance helicopter crash',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'ambulance right outside work',
#  '\x89ûïleoblakecarter dog think he ambulance',
#  'happening hatzolah em ambulance responding dual siren and\x89û',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'twelve feared killed pakistani air ambulance helicopter crash worldnews',
#  'twelve feared killed pakistani air ambulance helicopter crash worldnews',
#  'whats police ambulance number lesotho body know',
#  'medic aaceorg surprised still standardised clinical practice across nh ambulance trust',
#  'twelve feared killed pakistani air ambulance helicopter crash',
#  'people try jwalk ambulance passing hate',
#  'episode trunk annihilated freiza cleanest shit ever showed nigga mercy',
#  'shall annihilated petebests dessicated laid bare shall kneel',
#  'uribe annihilated baseball mets',
#  'marksmaponyane heysundowns annihilated previous meeting celticindeed improvement',
#  'volfan tneazzy mizzou annihilated florida past season even ended muschamps career cant compete bama',
#  'annihilated ab',
#  'annihilated status education mba behalf easy street careen eovm',
#  'luka die everything annihilated alois trancy',
#  'acarewornheart good un fella sorry wont get annihilated',
#  'cop pull drunk driver safety second car hit train via viralspell',
#  'must annihilated',
#  'cop pull drunk driver safety second car hit train via viralspell',
#  'boom country entirely annihilated h\x89û \x89ûó britain',
#  'amirkingkhan would annihilated might well thank floydmayweather',
#  'one thing suregod promised israel annihilated butthe horror iran wnukes',
#  'violentfeminazi guess thats ok armenian since weve spent history getting annihilated',
#  'year since annihilated people instantly became aware ability annihilate whole humanity',
#  'day tryout went good minus fact stopped quickly get short ball annihilated toenail injury even',
#  'oryx symbol arabian peninsula annihilated hunter',
#  'luka die everything annihilated alois trancy',
#  'ready get annihilated bucs game',
#  'philipduncan breakfastone people annihilated last night weather really philip thought would forecast',
#  'domain sophistication annihilated closely uptotheminute feat zrnf',
#  'stormbeard steellord seen juda priest rob came back scorpion support fucking annihilated place astonishing gig',
#  'officially skipping fantasticfourfantsticwhatever hashtag getting annihilated review bummer',
#  'tomcatarts thus explaining annihilated case survivor evolved became godlike',
#  'completely annihilated cech paul keegan time alive',
#  'tomcatarts annihilated legion survivor imperfect hybrid project quickly formed new secret cell',
#  'sirbrandonknt exactly thats lesnarcena match summerslam last year great brock annihilated guy who',
#  'cop pull drunk driver safety second car hit train via viralspell',
#  'annihilated damascus syrian army grind \x89û÷alloosh gang manure pile',
#  'thatdes ok wasnt completely forthright may also food coma bc kebabtahinipickles also annihilated wfries',
#  'fun filled happyhour simmons bar camden handsome one got annihilated apart game',
#  'juanny beisbol sr annihilated ball lgm',
#  'rvfriedmann hell fraction belief total annihilation destruction usa lodisilverado ritzyjewels',
#  'potus maybe call israel tell sorry pres sold river annihilation',
#  'evildead annihilation civilization',
#  'u national park service tonto national forest stop annihilation salt river wild horse via change',
#  'annihilating quarterstaff annihilation',
#  'world annihilation v self transformation alien attack exterminate human',
#  'starmade stardate planetary annihilation via youtube',
#  'u national park service tonto national forest stop annihilation salt river wild horse via change',
#  'u national park service tonto national forest stop annihilation salt river wild horse via change',
#  'kimkardashian please sign share petition save wild horse arizona',
#  'u national park service tonto national forest stop annihilation salt river wild horse via change',
#  'theellenshow please check salt river horse help stop annihilation happen without signatureschange org thx',
#  'soul punished withåêannihilation',
#  'calfreedommom steph mention major contributor annihilation israel',
#  'willienelson need help horse dieplease rt amp sign petitiontake stand amp voice gilbert',
#  'reject law misguided false prophet imprison nation fueling self annihilation',
#  'u national park service tonto national forest stop annihilation salt river wild horse via change',
#  'annihilation jeb christie amp kasich le hour away please god allow least one full day',
#  'barbitwins need helphorses die please rt amp sign petition take stand amp voice gilbert',
#  'whippenz need help horse dieplease rt amp sign petitiontake stand amp voice gilbert',
#  'hey az sign petition save wildhorses tantonationalforest rollingstones singalong order',
#  'stop annihilation salt river wild horse via change',
#  'sonofbaldwin he current nova bookslast checkedhe tied book rider died annihilation',
#  'u national park service tonto national forest stop annihilation salt river wild horse via change',
#  'please sign amp rt save saltriverwildhorses',
#  'thanks count dante join u following annihilation zone johnny',
#  'world annihilation v self transformation alien attack exterminate human',
#  'u national park service tonto national forest stop annihilation salt river wild horse via change',
#  'u national park service tonto national forest stop annihilation salt river wild horse via change',
#  'im gon na fight taylor soon get',
#  'ohh fukurodani didnt survive apocalypse bokuto feel horrible poor boy ppor child',
#  'another jocelyn birthday apocalypse',
#  'rt janenelson rt stephenscifi adaptation watch charlie human apocalypse optioned film sciencefiction \x89û',
#  'apocalypse please',
#  'another hour august pm here red rover zombie apocalypse internetradio collegeradi\x89û',
#  'honeybunzgem primalkitchen feel like pullup one stage apocalypse',
#  'shes kinda hot played radio today whats next disease apocalypse started everyone careful',
#  'apocalypse lol gf',
#  'know question interpretation sign apocalypse called',
#  'julie r apocalypse version romeo juliet warmbodies',
#  'apocalypse upon u',
#  'rt fittscott minecraft night lucky block mod bob apocalypse wither amp mod showcase popularmmos vi\x89û',
#  'begin day one snow apocalypse',
#  'rt ourmothermary short reading apocalypse spirit angel took top enormous high mountain \x89û',
#  'candylit imagine sarumi zombie apocalypse fighting back back heart heart conversation',
#  'rt zonewolf liked youtube video minecraft night lucky block mod bob apocalypse wither amp mo\x89û',
#  'thats planet lone audience apocalypse',
#  'dad bought dvd look like science doc front read back actually impending biblical apocalypse',
#  'alexandrapullin indeed apocalypse come week know ill',
#  'go look grizzly peak right look like beginning dystopian apocalypse movie',
#  'niece asked would scared apocalypse',
#  'there storm cairo latest xmen apocalypse set photo via yahootv',
#  'minecraft night lucky block mod bob apocalypse wither amp mod showcase popularmmos via youtube',
#  'shot heart xv going totally give love bad name heart pierc',
#  'rt geekapocalypse pm gmt hesse play dark soul day etcpb',
#  'know go zombie take',
#  'latest bryansinger reveals storm queen apocalypse rupaul',
#  'shadow boxing apocalypse',
#  'short reading apocalypse spirit angel took top enormous high mountain',
#  'enjoyed liveaction attack titan every time see poster im reminded freshly clean coiffed everyone apocalypse',
#  'liked youtube video minecraft night lucky block mod bob apocalypse wither amp mod showcase',
#  'pbban temporary armageddon kill flag fast xp reason',
#  'pbban temporary russaky armageddon kill flag fast xp reason',
#  'official vid doublecups gtgt gtgt trubgme prod thisizbwright gtgt armageddon',
#  'ouvindo peace love amp armageddon',
#  'best movie youve ever seen armageddon',
#  'bed time dont wake unless revolution armageddon start',
#  'red faction armageddon microsoft xbox full read ebay',
#  'katiekatcubs already know shit go world series armageddon',
#  'rt ophiuchus love truelove romance lith voodoo seduction astrology rtrrt lotz apocalypse armageddon pla\x89û',
#  'im gon na beat armageddon hsu hao got flawless first try',
#  'enews ben afflecki know there wifekids girl cant help ive loved since armageddon eonlinechat',
#  'id long coat hand id worn certainty armageddon bear sense occasion',
#  'phone spying hidden back door nsa data mining software financial armageddon blog',
#  'pbban temporary hyiderghost armageddon kill flag fast xp reason',
#  'rt rtrrtcoach love truelove romance lith voodoo seduction astrology rtrrt lotz apocalypse armageddon planet\x89û',
#  'pbban temporary fighterdena armageddon kill flag fast xp reason',
#  'photo sketch based taste armageddon episode startrek tos',
#  'armageddon',
#  'aberdeenfc aberdeenfanpage good luck tomorrow night get coefficient point plz armageddon',
#  'paddytomlinson armageddon',
#  'rohnertparkdps youre another one history book thank justice department way havent paid income tax yr',
#  'vladimir putin issue major warning late escape armageddon',
#  'god kingdom heavenly govt rule people earth armageddon',
#  'l b entertainment lot brucewillis movie dvd die hard monkey armageddon sixth ebay auction',
#  'let\x89ûªs talk goof guild saunders come right stage',
#  'karnythia niece gaining ability stand im getting prepared toddler apocalypse armageddon',
#  'check preppers doomsday must library collection cd shtf preppertalk survival prepper via ebay',
#  'erker eep thought yesterday saw hella scary hail armageddon',
#  'ahamedis think messiah already come year ago armageddon dajaal gog amp magog',
#  'sadly window reveals microsofts ethic armageddon',
#  'armageddon averted el patron ultimalucha',
#  'samihonkonen time hour latest series ww blueprint armageddon extremely impressive',
#  'european fitba till christmas armageddon',
#  'christian united israel cufi jew convert soon die armageddon u',
#  'official vid gt doublecups gtgt gtgt trubgme prod thisizbwright gtgt armageddon',
#  'tomorrow day start armageddon preseasonworkouts',
#  'lee comedy \x89ûïleejasper working class tory prepare armageddon interestraterise\x89û\x9d',
#  'chart prove financial crisis part begun financial armageddon economic collapse blog track tren',
#  'paul craig robert \x89ûò vladimir putin issue major warning late escape brics robert russia',
#  'rohnertparkdps youre stage right light isnt funny get goofball staff pd',
#  'official vid thereal gtgtgt gtgtgt trubgme gtgtgt armageddon comin soon',
#  'well done celtic finger crossed aberdeen tomorrow night armageddon eh',
#  'beyonce pick fan army beyhive',
#  'one direction pick fan army directioners x',
#  'second summer pick fan army sosfam',
#  'beyonce pick fan army beyhive',
#  'beyonce pick fan army beyhive',
#  'one direction pick fan army directioners x',
#  'seeing army whitewalkers first thing slightly intrigued got far',
#  'build kingdom lead army victory start g friend code lzktjnox',
#  'salvation army host rally reconnect father child salvation army hosting back school rally\x89û',
#  'vote directioners v queen th round billboard fanarmyfaceoff',
#  'build army dog leader lion dog fight like lion',
#  'show hero tv review',
#  'one direction pick fan army directioners x',
#  'infantry men lume dial army analog quartz wrist watch sport blue nylon fabric full rea\x89û',
#  'one direction pick fan army directioners x',
#  'victorinox swiss army date woman rubber mop watch',
#  'rt drayesha indiakomuntorjawabdo indian army ki\x89û',
#  'second summer pick fan army sosfam ìñ',
#  'beyonce pick fan army beyhive',
#  'one direction pick fan army directioners x',
#  'da one mtvsummerstar videoveranomtv mtvhottest britney spear lana del rey',
#  'one direction pick fan army directioners',
#  'stony jackson america last hope lead army felon thus army reject army satan',
#  'wwi wwii japanese army navy military japan leather watch war mido ww full read ebay',
#  'beyonce pick fan army beyhive',
#  'beyonce pick fan army beyhive',
#  'beyonce pick fan army beyhive',
#  'beyonce pick fan army beyhive',
#  'potus appoints brig gen richard g kaiser member mississippi river commission learn mrc',
#  'ap violent country get army involved help control killing bring back peace poor people',
#  'wwi wwii japanese army navy military japan leather watch war mido ww full read ebay',
#  'wwi wwii japanese army navy military japan leather watch war mido ww full read ebay',
#  'one direction pick fan army directioners x',
#  'one direction pick fan army directioners',
#  'two jewish terrorist charged historicchurch arson ugly truth',
#  'spokane authority say theyre struggling solve arson case like today hamilton',
#  'thousand attend rally organized peace protesting arson attack took life',
#  'add familia arson squad',
#  'another fake hate crime lesbian burn house else new',
#  'los angeles time arson suspect linked fire caught northern newsintweets',
#  'mourning notice stabbing arson victim stir \x89û÷politics grief\x89ûª israel',
#  'mourning notice stabbing arson victim stir \x89û÷politics grief\x89ûª israel',
#  'sound arson',
#  'owner chicagoarea gay bar admits arson scheme lgbt',
#  'wait',
#  'arson suspect linked fire caught northern california',
#  'trial date set man charged arson burglary',
#  'death palestinian toddler arson attack israel crack jewish',
#  'palestinian teen killed amid protest arson attack',
#  'kisii police kisii hunt student failed arson plot police kisii hunt student countynews',
#  'mariah getting thick shoulder poor girl',
#  'mourning notice stabbing arson victim stir \x89û÷politics grief\x89ûª israel poster shira banki',
#  'relaxinpr miprv rt latimes arson suspect linked fire caught northern california',
#  'jewish leader prayed hospital palestinian family treated arson via huffpostrelig',
#  'owner chicagoarea gay bar admits arson scheme via theadvocatemag lgbt',
#  'saynae angel arson',
#  'kisii police kisii hunt student failed arson plot police kisii hunt student countynews',
#  'mourning notice stabbing arson victim stir \x89û÷politics grief\x89ûª israel',
#  'owner chicagoarea gay bar admits arson scheme via theadvocatemag lgbt',
#  'owner chicagoarea gay bar admits arson scheme lgbt',
#  'mourning notice stabbing arson victim stir \x89û÷politics grief\x89ûª israel',
#  'owner chicagoarea gay bar admits arson scheme lgbt',
#  'arson suspect linked fire caught northern california via latimes',
#  'tennessee lesbian couple faked hate crime destroyed home arson\x89û lesbian',
#  'arson suspect linked fire caught northern california los angeles time',
#  'arson suspect linked fire caught northern california',
#  'dc cloudygoldrush hate white people mo',
#  'nowplaying arsonist mc impressed arsonistmusic',
#  'alleged east bay serial arsonist arrested',
#  'safyuan minor citation possesion decriminalized substance im facing time',
#  'suspected serial arsonist arrested calif',
#  'arson suspect linked fire caught northern california',
#  'localarsonist diamorfiend legal system never forgets',
#  'casperrmg u dick',
#  'bloorossington arsonist also burned mattress northumberland st cbcto',
#  'wheres arsonist',
#  'dont anything nice say come sit',
#  'vegetarian vegan video show arsonist torching popular bk restaurant strictly vegetarian govegan uniteblue',
#  'arsonist arrested setting many fire watch tonight\x89ûªs headline nightbeat veronicadlcruz minutemix',
#  'video capture man removing american flag long beach ca home burning arsonist sought',
#  'hif trick think nasty thing',
#  'spotlight take paradise arsonist mc wniagospel arsonistmusic',
#  'make',
#  'town salem melted ice cube bc im arsonist',
#  'arsonist blamed blaze plastic recycling business adelaide pcaldicott report newsadl',
#  'hotboy shit',
#  'zodiac girl feat trey dupree produced sparkz beatz chuck da arsonist',
#  'localarsonist lmfao',
#  'alleged east bay serial arsonist arrested sanfrancisco',
#  'doofus diamorfiend im jokin still cant move',
#  'localarsonist guess u say shit thinking',
#  'arsonist set nyc vegetarian restaurant fire police newyork',
#  'liked youtube video slimebeast town salem win arsonist',
#  'casperrmg bestcomedyvine whats cracking cuz',
#  'smoke good fuck eat drink drive nice car wear green mink',
#  'kill got court day earl',
#  'localarsonist lmao real live go',
#  'owner chicagoarea gay bar admits arson scheme frank elliott pleaded guilty hiring arsonist',
#  'trusting iran stop terrorism like inviting arsonist join fire brigade telegraph',
#  'big top burning true story arsonist missing girl \x89û',
#  'stay vigilent civil liberty constant attack nativehuman myreligion',
#  'credit pfannebeckers inspiring rediscover fantabulous tbt',
#  'nashville theater attack gun grabber demand \x89ûïhatchet control\x89û\x9d',
#  'breaking terror attack police post udhampur',
#  'demi stans really think heart attack sold million copy',
#  'scare there new version nuclear attack warning like knowing government still prepare',
#  'isil claim suicide bombing saudi mosque killed least',
#  'dattomm funniest part twitter feminist try attack head',
#  'horrific attack wife muslim italy liveleak news',
#  '\x89ûª blast accused yeda yakub dy karachi heart attack mumbai',
#  'etribune u drone attack kill suspected militant north waziristan acebreakingnews',
#  'suspect latest theater attack psychological issue',
#  'militant attack police post udhampur spos injured livemint allthenews',
#  'breaking obama official gave muslim terrorist weapon used texas attack',
#  'delhi government provide free treatment acid attack victim private hospital',
#  'new post darkreading new smb relay attack steal user credential internet',
#  'israeli force raid home alleged car attack suspect palestine',
#  'heart attack thought goat dead dont worry rocket okay',
#  'im gon na lie im kinda ready attack senior year',
#  'left hand side diamond graveyard shift attack defend right handside fucking idiot',
#  'volleyball attack ii volleyball training machine set simulation',
#  'notleys tactful yet direct response harper attack alberta govt hell yeah premier ableg cdnpoli',
#  'police assailant latest u movie theatre attack homeless psychological issue',
#  'caixxumsos thanks damn heart attack',
#  'suspect latest u theatre attack psychological issue',
#  'india shud give evidence pakthey share terrorist amp use next attackshare oth contries',
#  'illegal alien released obamadhs time charged rape amp murder santa maria ca woman prior offense',
#  'strongly condemn attack ary news team karachi cowardly act simply trying job',
#  'nashville theater attack gun grabber demand \x89ûïhatchet control\x89û\x9d',
#  'fact atomic bomb called little boy fat man say lot mentality went attack',
#  'blazerfan everyone see ignoranceshe latinoand ever benothing morebut attack dog hate group gop',
#  'heart disease prevention secondhand smoke',
#  'daytonarea org tell hit cyber attack',
#  'attack titan game p vita yay cant wait',
#  'infowars nashville theater attack gun grabber demand \x89ûïhatchet control\x89û\x9d nwo',
#  'anxiety attack',
#  'dog attacked food pugprobs',
#  'cop injured gunfight militant attack udhampur police post suspected militant attacked police post',
#  'envw nickcocofree juliedicaro jdabe asked feel attacked julie asked frail',
#  'messeymetoo feel attacked',
#  'im feeling attacked',
#  'black men didnt make way white men black men getting attacked',
#  'cant believe fucking ci female going somehow claim offended transgendered female who attacked medium',
#  'israeli helicopter attacked civilian gaza completed exercise greece',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'pt unit attacked responsible targeting muslim scholar imprisoning youth',
#  'telnet attacked streamyxhomesouthern',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'tbt remember time patrick kane attacked cab driver',
#  'im feeling attacked',
#  'ik troll pol rival never literally abused attacked family literally abuse ik loosers',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'envw nickcocofree juliedicaro jdabe worst person questioning julie attacked guy empathy',
#  'kelly osbourne attacked racist donald trump remark latino view',
#  'eunicenjoki need chill answer calmly like shes attacked',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'attacked robotlvl ive earned total free satoshis robotcoingame bitcoin freebitcoin',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'christinalavv lindsaywynn saw tweet feel really attacked',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'tv program saw said u air plane flew uranium mine fukushima attacked machine gun student army digging',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'mageavexis lt thing get attacked',
#  'christian attacked muslim temple mount waving israeli flag via pamela geller',
#  'welovela nhlducks avalanche defense match v st louis blue sportsroadhouse',
#  'liked youtube video kalle mattson avalanche official video',
#  'well crash like avalanche',
#  'colorado avalanche men official colorado avalanche reebok tshirt xl blue cotton nhl hockey',
#  'tix frozen fury xvii los angeles king v avalanche rowaa mgm grand',
#  'bet didnt know kick box',
#  'little piece wrote avalanche design blog id appreciate greatly checked',
#  'patrick roy upper deck spx finite made colorado avalanche mint',
#  'musician kalle mattson recreates classic album cover clever music video avalanche',
#  'beautiful sweet avalanche faith akito rose lot frothy gyp weddinghour',
#  'tix calgary flame v col avalanche preseason scotiabank saddledome',
#  'secret avalanche catechize inner self confidential communication respect creating worth len',
#  'fall leaf poplar fully ordained tumbling avalanche spurgeon',
#  'saw two great punk band making original music last week check em ghostoftheav montroseband',
#  'great performance chip fuelgas saver chevy tahoeblazeravalanches',
#  'musician kalle mattson recreates classic album cover clever music video \x89û÷avalanche\x89ûª',
#  'driving avalanche car week like driving tank',
#  'free ebay sniping rt chevrolet avalanche ltz lifted x truck please favorite amp share',
#  'chiasson sen cant come deal coloradoavalanche avalanche',
#  'paul rudd emile hirsch david gordon green prince avalanche qampa filmmaker google entretenimento video',
#  'great one time deal avalanche music purchase get neal rigga shirt',
#  'bigperm drafted avalanche rd overall played last season utahgrizz',
#  'got video rapper got song',
#  'funkflex yo flex im',
#  'avalanche one world away make believing im wide awake',
#  'possible new jersey avalanche next year',
#  'feat watch bts kallemattsons incredible music video avalanche',
#  'avalanche city sunset nowplay listen radio',
#  'chevrolet avalanche lt lt used l v v automatic wd pickup truck premium b\x89û',
#  'snowflake avalanche ever feel responsible',
#  'star war power jedi collection battle droid hasbro full read ebay',
#  'civil war general battle bull run hero colonel nd new hampshire letter signed',
#  'dragon ball z battle god rotten tomato via rottentomatoes',
#  'added video youtube playlist world tank battle assistant mod bat chat arti kaboom',
#  'ya boy clip v kus full battle moferadio heavybag battledom qotring battlerapchris hughes',
#  'indeed fully aware battle support fight',
#  'petersens bowhunting battle bow make sure head cast vote',
#  'tb throwback want battle here war',
#  'kelby tomlinson mildmannered nd baseman great metropolitan team fight neverending battle hit rbi sfgiants way',
#  'black eye space battle occurred star involving fleet totaling ship destroyed',
#  'really happened taken king story trailer space battle ripped hole saturn eytay neursis',
#  'battle animation fucking much',
#  'see happens battle block cbsbigbrother finally',
#  'du gon get rap battle',
#  'thing battle internal v external motivation',
#  'check item got phantasmal cummerbund warcraft',
#  'young german stormtrooper engaged battle somme ìñ',
#  'liked youtube video marvel v dc avenger battle',
#  'utahcanary sigh daily battle',
#  'sexydragonmagic ive come realization dont attention span mass battle game painting playing',
#  'detroitpls interested see win battle',
#  'battle goat',
#  'star war power jedi collection battle droid hasbro full read ebay',
#  'black eye space battle occurred star involving fleet totaling ship destroyed',
#  'lonepine remembered around australia descendant grow via canberra gallipoli ww',
#  'miss gary buseys son play dixie electronic green fiddle postbattle celebration sequence',
#  'news fedex longer transport bioterror germ wake anthrax lab mishap',
#  'fedex longer transport bioterror germ via usatoday',
#  'usa today fedex longer transport bioterror pathogen newsintweets',
#  'fedex longer transport bioterror germ wake anthrax lab mishap via usatoday',
#  'jacksonville busines fedex stop shipping potential bioterror pathogen',
#  'fedex longer transport bioterror pathogen wake anthrax lab mishap',
#  'aphl responds fedex longer transport bioterror germ wake anthrax lab mishap',
#  'news fedex longer transport bioterror germ wake anthrax lab mishap say åêfedex tcot',
#  'fedex stop transporting bioterror germ lab mishap fedex stopped transporting certain research',
#  'fedex longer ship potential bioterror pathogen via atlbizchron',
#  'frontpage bioterror lab faced secret sanction rickperry doesnt make cut foxnews gopdebate usatoday',
#  'fedex longer transport bioterror germ wake anthrax lab mishap via usatoday',
#  'house energy ampamp commerce subcommittee hold hearing cdc oversight bioterror lab army anthrax mishap htt\x89û',
#  'fedex willing transport research specimen potential bioterror pathogen wake anthrax lab mishap',
#  'world fedex longer transport bioterror germ wake anthrax lab mishap',
#  'fedex longer transport bioterror germ wake anthrax lab mishap news phone apple mobile',
#  'rt alisonannyoung exclusive fedex longer transport research specimen bioterror pathogen wake anthrax lab mishap \x89û',
#  'hmmthis could problem researcher fedex longer transport select agent via usatoday',
#  'world fedex longer transport bioterror germ wake anthrax lab mishap',
#  'fedex longer transport bioterror germ wake anthrax lab mishap',
#  'fedex longer ship potential bioterror pathogen fedex corp nyse fdx longer deliver package',
#  'fedex longer ship potential bioterror pathogen atlanta business chronicle',
#  'thank fedex longer shipping live microbe department defense',
#  'nowplaying orchardalley le nyc bioterror manufactured fear state repression abcnorio garden',
#  'fedex longer transport bioterror germ via usatoday',
#  'jax biz journal fedex stop shipping potential bioterror pathogen',
#  'usatoday today frontpage bioterror lab faced secret sanction rickperry doesnt make cut foxnew\x89û',
#  'breakingnews fedex longer willing transport research specimen potential bioter\x89û',
#  'fedex longer transport bioterror germ wake anthrax lab mishap via usatoday',
#  'fedex stop shipping potential bioterror pathogen trucking',
#  'fedex longer transport bioterror germ wake anthrax lab mishap',
#  'fedex longer transport bioterror germ wake anthrax lab mishap',
#  'fedex longer shipping bioterror germ wxiatv scoopit',
#  'fedex longer transport bioterror germ wake anthrax lab mishap',
#  'usatoday today frontpage bioterror lab faced secret sanction rickperry doesnt make cut foxnew\x89û',
#  'fedex longer transport bioterror germ wake anthrax lab mishap via usatoday',
#  'biolab safety concern grow fedex stop transporting certain specimen research facility dumbfounded action',
#  'fight bioterrorism sir',
#  'liked youtube video fema region targeted bioterrorism nasa japan rocket launch lithium',
#  'anthrax bioterrorism cdc carry extensive review lab safety pathogen handling procedure',
#  'firepower lab electronic resource automation fight infectious disease bioterrorism \x89û',
#  'cagov blksampwhts colluded take wht f usagov auth hostageamp make look blk wbioterrorismampuse lglorg idis id still hersvp',
#  'darrellissa great iran deal cover bioterrorism got cut terrible keep good work',
#  'tale two pox body horror virus infectiousdiseases bioterrorism',
#  'bioterrorism public health superbug biolabs epidemic biosurveillance outbreak homeland security news wire',
#  'creation ai climate change bioterrorism mass automation workforce contact life wealth inequality yea weve got easy',
#  'lie trust dvd cia hollywood bioterrorism len horowitz vaccine nwo',
#  'omagazine satan daughter shadow warrior ft woman aka transgender mode p nyc fold extra extra center bioterrorism',
#  'drrichardbesser yes would think since college difficult think bioterrorism esp bc dispersed',
#  'volunteer needed participate emergency preparedness drill simulating bioterrorism disaster hvnewsnetwork',
#  'meyerbjoern thelonevirologi mackayim major american newspaper running series alleged bioterrorism research going n',
#  'fight bioterrorism sir',
#  'cdc pretty cool list bioterrorism agent',
#  'government expert concerned possible bioterrorism using gm organism scientist concerned',
#  'prepare u hhs selects regional special pathogen treatment center bioterrorism infectious ebola',
#  'stationcdrkelly support sys usagov auth taken hostage blk u clergyforced exist youngerampgrossly disfigured bioterrorismap',
#  'amp think possibility full transformation impossible dont quite like medical mystery bioterrorism suck',
#  'fight bioterrorism sir',
#  'book describing future therapy technology sport sexuality bioterrorism diagnosis digitalhealth hcsm',
#  'aphiabeta wugliness due uglyamesocialaction frat bioterrorismim who fbi id u tolewantg another homeabc',
#  'howardu blksampwhts colluded take wht f usagov auth hostageamp make look blk wbioterrorismampuse lglorg idis id still',
#  'fight bioterrorism sir',
#  'cspanwj blksampwhts colluded take wht f usagov auth hostageamp make look blk wbioterrorismampuse lglorg idis id still',
#  'onufrance bioterrorism rockefellerchirockefellerunivheiress evade lgl effort prosecute blks harvardu kidnapgafp',
#  'irandeal cover nuclear activity bioterrorism iran broken least agreement',
#  'threat anthrax cdc via cdcgov',
#  'bioterrorism authority allay glanders fear ahead rio olympic equestrian test event via horsetalknz',
#  'kaotixblaze craving u',
#  'ive pool day raisinfingers',
#  'know anyone looking move hammond share listing',
#  'life amazin time crazy nigga dey wan na blaze hate made took dedication n motivation',
#  'blaze bro',
#  'shayoly yes love',
#  'see virtual tour one listing fir st cannon beach listed dorrie caruana',
#  'pendleton medium office said fire base right horno blaze',
#  'welcome djryanwolf djcoreygrand djknyce djoneplustwo officialcoredjs family cleveland standup iamtonyneal',
#  'love living blaze inside apt balcony',
#  'bellalinn alrighty hit well blaze',
#  'blaze jay fuck dutch slave trade',
#  'hair poverty moment need get fade weekend get',
#  'property loss california wildfire nearly double weekold blaze rage',
#  'breaking firefighter battling blaze east cary condo building',
#  'nigga love hating',
#  'audacityjamesta dont like babe lt youll ball fun lan',
#  'liked youtube video iamrrsb minecraft skywars blaze que usa hack e flechadas sinistras',
#  'dems blaze covered month agochicago police detained thousand black american interrogation facility',
#  'yo got bar im even rapper',
#  'ugh blaze put calorie pizza ok cool thisispublichealth',
#  'pic blaze fort kid look like jackass stuffin face like',
#  'look like year writing computer ahead',
#  'beautifuljuic letting know',
#  'babysweet im mad name amp dont blaze',
#  'guiltygearxxacp yeah know blaze blue dont twitter lol drew week ago',
#  'socialmedia news new facebook page feature seek help personalize customer experience',
#  'djjohnblaze shout blaze hottest dj sothwest',
#  'liked youtube video minecraft episode blaze farm beginning',
#  'property loss california wildfire nearly double weekold blaze rage fire\x89û',
#  'christycroley work yet see new vela short blaze',
#  'uabstephenlong courtlizcamp total tweet fail beautiful inside blaze',
#  'mixtape coming promise goin right',
#  'itzsteven whopperjr huh leo started last year ever since people blaze back',
#  'bedroom bath sale palm ca youtube video',
#  'yes gun',
#  'acee daem girl smooth asf c',
#  'artisteoftheweekfact say conversation coastcoastdjs agree crystalblaz jiwonle hiphop clubbanger',
#  'bright amp blazing fireman birthday party wedding',
#  'real vibez radio blazing best vibez nowplaying listenlive',
#  'montgomery come blazing hot weatherstay std yet another rejected city slogan',
#  'come join u tomorrow august transcendblazing trail diversified world marketing',
#  'morgan silver dollar gem bu dmpl cameo rev blazing m high grade full read \x89û',
#  'morgan silver dollar gem bu dmpl cameo rev blazing m high grade full read \x89û',
#  'bowl got thinking damn ive blazing damn long',
#  'danryckert drewscanlon he blazing game best stealth skill yet nothing beat silenced',
#  'bit pacquiao v marquez unfilled blazing swarm online durvod',
#  'turn radio stoponesounds live airwave amp fm stickynyc root blazing hit',
#  'baseballquotes inch dynasty',
#  'im weapon master let go gun blazing hinatobot',
#  'blazingben pattyds gwfrazee joshuaassaraf really sadly come expect obama',
#  'shouout kasadlla cause vocal blazing hot like weather shes',
#  'sxleak phtos yr old ashwo lady festac town delta expsed bbm leaked picture',
#  'oh heart racing temperature blazing roof videoveranomtv fifth harmony',
#  'bethanymota haha love',
#  'dmac colorado spanish word latin origin meaning reddish colored dummy pronouncing wrong',
#  'traffic freezing cold blazing hot \x89ûò heat traffic',
#  'im crazy enough run degree midday heat blazing sun place im not\x89û',
#  'im blazing rn there nothing stop',
#  'still blazing',
#  'bekahw thanks sweat bullet every time get blazing sun beating',
#  'acousticmaloley blazing',
#  'officialtjonez lost word made new fan fam crazy skill beyond blessed keep blazing dude made love respect',
#  'let hot blazing fantasy escort gfe dubai',
#  'srajapakse thank missy thought suited blazing hot summertime yeehaw',
#  'asukager magical bag blazing',
#  'blazing elwoods blazingelwoods dont bother dougs song tune',
#  'morgan silver dollar p ch gem bu pl blazing m satin rare proof like full re\x89û',
#  'blazing hot etisalat free mb complete month etisalat giving mb tecno q ime',
#  'funkylilshack mariaf want full bitch slapping gun blazing cake throwing charles showdown worth wait',
#  'follow edwelchmusic check hit single unpacked man blazing',
#  'still dont know hour physical activity blazing sun isnt sport',
#  'way archetype bleeding wellgrounded readiness fpoj',
#  'threw chicken nugget sister lip bleeding',
#  'could slit throat id apologize bleeding',
#  'joe landolina gel make stop bleeding instantly arizona realestate',
#  'nose bleeding last one like year ago',
#  'bleeding typewriter day far ive written bunch gunk',
#  'jaydennotjared cant help hope youre ok text need talk sending hug way p bleeding death allowed',
#  'stab back promise youll one bleeding',
#  'apparently youre bleeding people look weird lol well fine keep walking',
#  'eating takis rubbing eye hand eye bleeding tear',
# ...
#  'coloiccarnality bleeding instinct kicked look away scratch back head',
#  'ear bleeding hate stefano',
#  'ear started bleeding',
#  'benjm tourofutah bgrego saw pileup tv keep racing even bleeding',
#  'rave wedding seeing eye bleeding',
#  'say bad thing happen reason wise word gon na stop te bleeding',
#  'damnaarielle yo timeline blew damn fast',
#  'mfalcon go look blew w atomic bomb',
#  'blew oomf instagrams cause shes cute shes active follower',
#  'bfowler see crazy line blew',
#  'instagram blew apparently featured jazz tonight cool love',
#  'id still team usagi even blew entire solar system airhead misstep',
#  'benkin mili remember u like blew one game u probs dont king cup',
#  'hate people tweet receipt know wrong wont take bc blew literally gtfo youre desperate',
#  'think blew hopeinhearts notification go check shes encouraging love',
#  'hw going dude keeping took exit pulled side told blew motor lolol fastfurious',
#  'universe might actually exist scientist say sun blew earth began',
#  'max blew tf shot fired catfishmtv',
#  'rick morty blew',
#  'codythompson ty blew motor went flame got ok',
#  'realized dude onlyftf way blew tusky game robsimss cantmisskid',
#  'night blew rq',
#  'blew snapchat reason',
#  'queen gambit went well anakin blew droid control ship oh well still fun cant stop next wbc',
#  'iphooey time ironically michele bachmann brought wron paul amp everyone blew called hoax finally right',
#  'catfish retweeted amp notification blew',
#  'guy whistled parking lot amp help wind blew skirt getting car',
#  'blew mention',
#  'st time someone blew phone time would blocked believe catfish',
#  'imawesome like literally blew',
#  'freya video blew everywhere',
#  'yahooschwab easy way look good ray rice fiascothat blew',
#  'lmao light skin guy blew twitter talking ugly kid',
#  'watched honey blew economy recommend conservative shoppe horror harperanetflixshow elxn stopharper',
#  'anyone else see fireball falling earth look like plane blew',
#  'ye thing big sean still blew',
#  'zayn blew twitter',
#  'bitch done blew shit',
#  'weloverobdyrdek adrianpeel damn clue tried see many click could get blew thats played',
#  'daorcey nsit great pair like couple graywardens fighting blight',
#  'damidnighter there actually theory magisters arent reason blight dwarf one',
#  'cycling fan feel sorry world athletics doping blight exacerbated monetary reward lot soul searching required',
#  'kynespeace blight',
#  'poor jack',
#  'realhotcullen agree knew wed going deep road found blight red lyrium aint yet gtgt',
#  'get load welfare loving spongea blight society',
#  'new post prysmian secures contract blight bank wind farm',
#  'cleveland height shaker height fight blight house next door',
#  'toddcalfee mattburgener wanted see info blight u got',
#  'carl everest rob cobes whitt blight frost leo snuff godly others drink beer someday',
#  'thda kick antiblight loan effort memphis',
#  'city program help turn blight greenspace tennessee housing development\x89û news',
#  'demetae yes want new blight leader',
#  'release planing level constellation blight gaia iclowns drumstep remix iclown infinity',
#  'cleveland height shaker height fight blight house next door',
#  'going achieve excellence big thing develop habit little matter dont know author',
#  'hendy sure purdies alive blight',
#  'tracy blight thank following',
#  'apperception bridgework blight xxhjesc',
#  'dotish blight car go right ahead mine',
#  'sexual revolutionblight woman story via acebabes healthweekly amateurnester',
#  'like swear secret well uncover old god slumber think there gon na another blight',
#  'willhillbet double result live app',
#  'parksboardfacts first zippoline one want use community never asked blight park moveit',
#  'look policy matter ohio report cle cuyahoga county blight greening vacant land soon',
#  'anellatulip put taint magisters open gate let blight get away',
#  'anellatulip theory make way much sense say dwarf may actual origin blight',
#  'palestinian refugee tragedy blight humanity amp shame every israeli living',
#  'article michael jackman metro time detroit group later downgraded estimate square mile',
#  'locksmithingart respecting elaboration blight lock lpdkl',
#  'jakeblight wealilknowa cunt',
#  'every win ranked play gave special card back would cool long te\x89û',
#  'amazon deal wait buy',
#  'new print available waiting long pamela blizzard',
#  'blizzarddraco give free art kamon',
#  'stevenontwatter pussyxdestroyer order blizzard pay put nut say ball flavored boom free ice cream',
#  'blizzard auz pm cst radioriffrocks hr rock make hump day complete',
#  'really want rolo blizzard mom said guess dq tonight',
#  'ashayo msmiggi hi ashayo believe vods youtube presentation nothing like seeing live',
#  'stats',
#  'tweettaiji dolphin worship group based superstition take look tweet',
#  'blizzardfans lucio let get overwatch hype train rolling caution though arent break',
#  'blizzardgamin ight',
#  'peanut butter cookie dough blizzard',
#  'mic controller arent working one second',
#  'tomorrow announcement vods',
#  'updated window get error',
#  'new expansion idea bard class holy trinity',
#  'daborsch really shocking blizzard lured old fanbase back wod disappointed u hardcore everyones leaving',
#  'best thing dq cotton candy blizzard',
#  'lizard wizard blizzard lwb',
#  'blizzarddraco lonewolffur need',
#  'fairxx playoverwatch blizzardcs please blizzard love',
#  'blizzard would clutch asf',
#  'blizzarddraco lonewolffur also please would much like link',
#  'bubblycuteone ok ok ima act right bout get blizzard tho',
#  'lonewolffur control tora',
#  'first time playing hearthstone pc thought',
#  'love cotton candy blizzard',
#  'tcgreno hard reset xbox',
#  'really wan na brownie batter blizzard',
#  'call little bit blizzard',
#  'market news activision blizzard cognizant technology first solar',
#  'sean end career sg blizzard v knockout',
#  'biggest regret hearthstone',
#  'someone walk dq wan na butterfinger blizzard bad',
#  'horrible moment u open dryer look like snowy blizzard cuz u left piece paper jean pocket',
#  'lonewolffur bruh dy',
#  'rip blood',
#  'chiefcg nah young blood cook gone im cut haha',
#  'wall invincible history blood dance floor',
#  'broke nailreal fake morning blood ah hurt idea treat help pretty please',
#  'star reviewer dragon blood boxset lindsay buroker kindle',
#  'blood group associated gastric carcinoma say text bookanother fragile gene body',
#  'friend like blood beside u always come wounded',
#  'gone get get blood',
#  'people tattoo u allowed donate blood receive blood well',
#  'dialysis grandpa oh lord blood make light headed',
#  'setzorah dad dont claim mean right look eye blood xbox smh',
#  'omron hemc automatic blood pressure monitor standard large bp cuff',
#  'blood pressure roof dont need extra shit',
#  'chamberedblood yeah speakingfromexperience',
#  'cant believe people mid dont high blood pressure life stressful decisionsondecisions',
#  'guy imouto isnt actually related blood',
#  'bruh white people buy ugliest shoe super tight blood going foot',
#  'another day another excellent dangerousbeans porridge seriously people blood orange porridge phenomenal',
#  'scotto happy birthday young blood',
#  'wasnt blood',
#  'kinda shii nasty blood pun intended',
#  'aint hoe blood',
#  'today hastle getting drug tested blood drown tb shot document filling',
#  'man somebody got ta stop sbee dude fuckin funny blood',
#  'wind take gypsy blood time',
#  'loboparanoico mad men',
#  'private thirsty nightsad blood rockn roll',
#  'rolandonabeats ellie goulding blood acesse nosso site para ouvir',
#  'olrules welcome read free chapter new book encounter jesus full hope',
#  'anthxvy run blood',
#  'sethalphaeus personal favorite include paramore muse green day royal blood so',
#  'shed innocent blood son daughter land polluted psalm help stop sin abortion',
#  'se pone cantar cry lightning',
#  'wasnt big stab deep stab there like blood everwhe',
#  'add item everyday eating habit please research take blood\x89û',
#  'bloody hell',
#  'infected bloody ear piercings always fun',
#  'aggressif bloody aggressive',
#  'entered win entire set butterlondon lip crayon via berams go enter bbloggers',
#  'slsandpet hey sally sorry emailed awol bloody work argh resigninshame',
#  'im listening bloody jay',
#  'lauradeholanda forrest version thats bloody awful well',
#  'nightmare elm street getting remade',
#  'cant bloody wait sony set date stephen king\x89ûªs \x89û÷the dark tower\x89ûª stephenking thedarktower bdisgusting',
#  'got ta try let go many bloody thing smh',
#  'tradcatknight russia may played reason link b okanowa bloody mainline invasion looked like bloody',
#  'bloody insomnia insomnia',
#  'zhenghxn tried eye akame ga kill tokyo ghoul damn bloody dont dare watch',
#  'fantosex suck thats youre bloody getting mean amends',
#  'call weekend call bloody mary time summer full new\x89û',
#  'bloody hell day havent even really done anything tired everything thought vaca would help much',
#  'damn bloody hot',
#  'mrtophypup bloody sexy drool',
#  'know say side effect low amp really fast son product acne cream side effect bloody diarrhea',
#  'ronda rousey would close making floyd mayweathers money fight bloody elbow boxing',
#  'im awful painting agree landscape bloody oil paint',
#  'need life sin girlfriend ride till bloody end girlfriend',
#  'itsmegss think well bloody barking',
#  'eh hello cover bloody thigh bloody cleav \x89ûó eh hello since expose cleavage',
#  'mariasherwood johnjcampbell mega bloody marvellous',
#  'bloody mary sink beet juice',
#  'melrises gayler jessienojoke melissaross monty python date bloody far want go',
#  'meet bloody r',
#  'friday supposed happy day bloody friday hah',
#  'chxrmingprince jonesluna bloody hope said folding arm sitting back chair',
#  'wait tell college friend reafs bloody mary drama cd',
#  'came kill indiansfor fun video smirking remorseless pakistani killer show boasting',
#  'ive watched episode se bloody monday bloodymonday tvshowtime',
#  'marlon williams gt elvis presley gt marlon williams gt steel panther shuffle mode like bloody legend',
#  'black friday turn bloody would rather shopping mystery',
#  'ezralevant someone told soccer mom getting pic blown put daughter bedroom wall',
#  'papcrdoll sg mention get blown choice deactivate leave good respect choice',
#  'manutd emilymcfcheslop wow wow club blown money fucked player like theyd pilloried',
#  'damn greinke got blown first inning',
#  'woke blown lol',
#  'aunt marge youre blown eheks',
#  'troylercraft yeah worth bc already many spammer amp twitter probably blown every second',
#  'white family supposedly representing america great value get blown horrible cgi nuclear strike',
#  'man hasnt machinegunkelly blown he still underground',
#  'mention blown wtf',
#  'thisdayinhistory confederate ship blown crew read via history',
#  'moment ur win mini uhc get blown creeper get kicked flying salty rn',
#  'libraryeliza get taylorswift bump approval probably he blown musicadvisory',
#  'truckload soldier blown nobody panic one little lion dy everyone loses mind',
#  'hey look kashs foundation live today got blown people magazine website todd blake',
#  'kaylak got last month went ee shop glad hasnt blown yet',
#  'first time tweet blown almost half day later',
#  'we\x89ûªre blown away extension nothing we\x89ûªve seen many option one',
#  'theboyofmasks thanks letting stay since manor blown anyways buddy',
#  'loner diary pattern sand may blown away photo two choked flame',
#  'even though bsg sufficiently hyped year somehow delayed watching utterly utterly blown away',
#  'vanessa game officially blown lady gentlementhe real show begin bb',
#  'guaranteed bitten mutant mosquito ankle blown little cunt',
#  'thing pick tozlet seat butt leprosy fullblown jerkface syndrome lateral lisp amp toilet rickets',
#  'kalinandmyles kalinwhite ig blown hacker need stop givebackkalinwhiteaccount',
#  'lukewinkie whoever directing video need grab nicki minaj someone u recognition mind blown',
#  'princessduck last week wanted th sense get blown far good james could win he huge target gone soon',
#  'orbette like blown amirite',
#  'dog\x89ûªs blown kennel \x89ûò bloody yorkshire terrorist',
#  'turn espn get blown',
#  'hopefulbatgirl went beaten blown next thing know ra al ghul brought back life escaped',
#  'thebriankrause leo as got metaphorically blown piperwearsthepants charmed',
#  'anarchicteapot boironusa zeno glononium c also help blown bashing bottle nitroglycerin book',
#  'new lady shoulder tote handbag woman cross body bag faux leather fashion purse full re\x89û',
#  'new lady shoulder tote handbag woman cross body bag faux leather fashion purse full re\x89û',
#  'son daughter would like see going war iran come back body bag let republican know',
#  'questergirl ditto way feel drank vodka ice would body bag',
#  'handbag genuine mulberry antony cross body messenger bag dark oak soft buffalo leather å£end date w',
#  'louis vuitton monogram sophie limited edition clutch cross body bag full read ebay',
#  'louis vuitton monogram sophie limited edition clutch cross body bag full read ebay',
#  'louis vuitton cultsierre monogram shoulder bag cross body bag',
#  'check ameribag healthy back bag shoulder cross body backpack khaki tan beige nylon ebay',
#  'photo bath amp body work cosmetic bag periwinkle blue copper piping along top four corner',
#  'new lady shoulder tote handbag woman cross body bag faux leather fashion purse full re\x89û',
#  'new summer long thin body bag hip word skirt blue',
#  'å¤ new lady shoulder tote handbag faux leather hobo purse cross body bag woman rt en\x89û',
#  'trjdavis bruh wan na fight im meet cage bro better find youre dealing end body bag',
#  'new lady shoulder tote handbag faux leather hobo purse cross body bag woman full read\x89û',
#  'auth louis vuitton brown saumur cross body shoulder bag monogram full read\x89û',
#  'check vintage longaberger floral fabric shoulder cross body bag brown leather strap ebay',
#  'new lady shoulder tote handbag faux leather hobo purse cross body bag woman',
#  'new summer long thin body bag hip word skirt blue',
#  'ìü new lady shoulder tote handbag faux leather hobo purse cross body bag woman rt en\x89û',
#  'louis vuitton monogram sophie limited edition clutch cross body bag full read ebay',
#  'new woman handbag faux leather lady shoulder tote cross body bag large satchel full re\x89û',
#  'new lady shoulder tote handbag faux leather hobo purse cross body bag woman',
#  'one day heart gone get zipped body bag',
#  'handbag fashion style authentic louis vuitton pochette bosphore shoulder cross body bag\x89û',
#  'å new lady shoulder tote handbag faux leather hobo purse cross body bag woman',
#  'handbag fashion style vintage coach purse camera bag cross body bid \x89û',
#  'genuine leather man bag messenger fit ipad mini tablet case cross body air jp full rea\x89û',
#  'louis vuitton monogram sophie limited edition clutch cross body bag full read ebay',
#  'new lady shoulder tote handbag faux leather hobo purse cross body bag woman',
#  'nuu fam fwt im leave body bag',
#  'new lady shoulder tote handbag faux leather hobo purse cross body bag woman full read\x89û',
#  'rhee deliciousvomit im im saying theyre lucky go home family put body bag',
#  'mattbez oh im bagging body bangin im saying shes going get rose',
#  'ohmyloz rondarousey bagging body shes smoking hot',
#  'drake really body bagging meek',
#  'fuckyeahcarey bornverified drake killing dude tea bagging dead body point',
#  'meekmill wreck league ball drake olympic level body bagging like career nothing trollingtilmeekdiss',
#  'idgaf tough canada north philly meek acting like bitch amp drake body bagging as track',
#  'yankee body bagging mf',
#  'broseidonrex dapurplesharpie skimmed twitter missed body bagging',
#  'g body bagging lyrically',
#  'bomairinge elutranscendent straight body bagging',
#  'body bagging bitch',
#  'better feeling seeing stage day one year friendship still body bagging mics together',
#  'mopheme bigstar johnson problem game body bagging nigga vuzuhustle',
#  'body bagging todaygot post score',
#  'editaxohaze let bagging body begin lol aint cuffed yet shouldnt bad',
#  ...]

# %%
# #install autocorrect
# !pip install autocorrect
# from autocorrect import Speller

# %%
# #create function to spell check strings
# def spell_check(sentence):
#     spell = Speller(lang='en')
#     return " ".join([spell(word) for word in sentence.split()])

# #showcase spellcheck 
# mispelled = 'Pleaze spelcheck this sentince'
# spell_check(mispelled)
# phrase= 'realized dude onlyftf way blew tusky game'
# spell_check(phrase)

# %%
token = Tokenizer()
token.fit_on_texts(text)

# %%
vocab_size = len(token.word_index) + 1
vocab_size
# Out:
# 15688

# %%
dict_token_tweet = token.index_word
dict_token_tweet
# Out:
# {1: 'fire',
#  2: 'like',
#  3: 'amp',
#  4: 'im',
#  5: 'get',
#  6: 'u',
#  7: 'new',
#  8: 'via',
#  9: 'one',
#  10: 'people',
#  11: 'news',
#  12: 'dont',
#  13: 'time',
#  14: 'video',
#  15: 'emergency',
#  16: 'disaster',
#  17: 'year',
#  18: 'body',
#  19: 'day',
#  20: 'building',
#  21: 'police',
#  22: 'home',
#  23: 'family',
#  24: 'would',
#  25: 'still',
#  26: 'say',
#  27: 'life',
#  28: 'go',
#  29: 'crash',
#  30: 'storm',
#  31: 'got',
#  32: 'california',
#  33: 'back',
#  34: 'look',
#  35: 'burning',
#  36: 'know',
#  37: 'bomb',
#  38: 'suicide',
#  39: 'world',
#  40: 'train',
#  41: 'flood',
#  42: 'see',
#  43: 'car',
#  44: 'man',
#  45: 'death',
#  46: 'attack',
#  47: 'rt',
#  48: 'first',
#  49: 'love',
#  50: 'pm',
#  51: 'going',
#  52: 'cant',
#  53: 'nuclear',
#  54: 'make',
#  55: 'two',
#  56: 'today',
#  57: 'war',
#  58: 'youtube',
#  59: 'dead',
#  60: 'killed',
#  61: 'accident',
#  62: 'want',
#  63: 'need',
#  64: 'let',
#  65: 'full',
#  66: 'woman',
#  67: 'hiroshima',
#  68: 'think',
#  69: 'may',
#  70: 'take',
#  71: 'weapon',
#  72: 'good',
#  73: 'watch',
#  74: 'way',
#  75: 'many',
#  76: 'wildfire',
#  77: 'last',
#  78: 'bag',
#  79: 'service',
#  80: 'injury',
#  81: 'could',
#  82: 'na',
#  83: 'collapse',
#  84: 'work',
#  85: 'bombing',
#  86: 'plan',
#  87: 'help',
#  88: 'best',
#  89: 'right',
#  90: 'come',
#  91: 'mh',
#  92: 'even',
#  93: 'thing',
#  94: 'army',
#  95: 'mass',
#  96: 'really',
#  97: 'school',
#  98: 'please',
#  99: 'lol',
#  100: 'hostage',
#  101: 'fatality',
#  102: 'another',
#  103: 'fear',
#  104: 'youre',
#  105: 'black',
#  106: 'city',
#  107: 'forest',
#  108: 'kill',
#  109: 'feel',
#  110: 'hot',
#  111: 'photo',
#  112: '\x89û',
#  113: 'fatal',
#  114: 'much',
#  115: 'god',
#  116: 'northern',
#  117: 'water',
#  118: 'house',
#  119: 'w',
#  120: 'great',
#  121: 'obama',
#  122: 'legionnaire',
#  123: 'bomber',
#  124: 'cause',
#  125: 'never',
#  126: 'wreck',
#  127: 'live',
#  128: 'read',
#  129: 'state',
#  130: 'hit',
#  131: 'latest',
#  132: 'old',
#  133: 'casualty',
#  134: 'every',
#  135: 'wave',
#  136: 'damage',
#  137: 'japan',
#  138: 'report',
#  139: 'atomic',
#  140: 'flame',
#  141: 'top',
#  142: 'said',
#  143: 'thats',
#  144: 'getting',
#  145: 'shit',
#  146: 'stop',
#  147: 'thunderstorm',
#  148: 'change',
#  149: 'near',
#  150: 'truck',
#  151: 'ever',
#  152: 'hope',
#  153: 'wind',
#  154: 'oil',
#  155: 'content',
#  156: 'earthquake',
#  157: 'everyone',
#  158: 'siren',
#  159: 'movie',
#  160: 'show',
#  161: 'fall',
#  162: 'evacuation',
#  163: 'rain',
#  164: 'coming',
#  165: 'set',
#  166: 'night',
#  167: 'found',
#  168: 'run',
#  169: 'since',
#  170: 'girl',
#  171: 'warning',
#  172: 'military',
#  173: 'official',
#  174: 'well',
#  175: 'weather',
#  176: 'without',
#  177: 'boy',
#  178: 'injured',
#  179: 'as',
#  180: 'flooding',
#  181: 'next',
#  182: 'th',
#  183: 'game',
#  184: 'debris',
#  185: 'story',
#  186: 'cross',
#  187: 'malaysia',
#  188: 'smoke',
#  189: 'keep',
#  190: 'update',
#  191: 'area',
#  192: 'bus',
#  193: 'end',
#  194: 'head',
#  195: 'little',
#  196: 'call',
#  197: 'child',
#  198: 'terrorist',
#  199: 'gon',
#  200: 'check',
#  201: 'guy',
#  202: 'face',
#  203: 'food',
#  204: 'sound',
#  205: 'post',
#  206: 'wounded',
#  207: 'confirmed',
#  208: 'severe',
#  209: 'always',
#  210: 'st',
#  211: 'fucking',
#  212: 'road',
#  213: 'job',
#  214: 'wild',
#  215: 'refugee',
#  216: 'migrant',
#  217: 'reddit',
#  218: 'there',
#  219: 'heat',
#  220: 'bad',
#  221: 'fan',
#  222: 'natural',
#  223: 'sinking',
#  224: 'thunder',
#  225: 'someone',
#  226: 'also',
#  227: 'bloody',
#  228: 'murder',
#  229: 'he',
#  230: 'liked',
#  231: 'lightning',
#  232: 'loud',
#  233: 'ive',
#  234: 'summer',
#  235: 'week',
#  236: 'screaming',
#  237: 'lot',
#  238: 'high',
#  239: 'missing',
#  240: 'made',
#  241: 'evacuate',
#  242: 'spill',
#  243: 'shot',
#  244: 'explosion',
#  245: 'free',
#  246: 'minute',
#  247: 'blood',
#  248: 'hour',
#  249: 'save',
#  250: 'yr',
#  251: 'outbreak',
#  252: 'panic',
#  253: 'baby',
#  254: 'hurricane',
#  255: 'bridge',
#  256: 'riot',
#  257: 'failure',
#  258: 'trapped',
#  259: 'collided',
#  260: 'breaking',
#  261: 'tonight',
#  262: 'air',
#  263: 'eye',
#  264: 'phone',
#  265: 'ambulance',
#  266: 'destroy',
#  267: 'whole',
#  268: 'survivor',
#  269: 'survive',
#  270: 'business',
#  271: 'released',
#  272: 'attacked',
#  273: 'derailment',
#  274: 'wreckage',
#  275: '\x89ûò',
#  276: 'issue',
#  277: 'island',
#  278: 'sign',
#  279: 'hail',
#  280: 'friend',
#  281: 'destroyed',
#  282: 'fuck',
#  283: 'saudi',
#  284: 'explode',
#  285: 'ruin',
#  286: 'rescue',
#  287: 'sinkhole',
#  288: 'market',
#  289: 'around',
#  290: 'burned',
#  291: 'heart',
#  292: 'trauma',
#  293: 'destruction',
#  294: 'part',
#  295: 'light',
#  296: 'charged',
#  297: 'big',
#  298: 'harm',
#  299: 'landslide',
#  300: 'survived',
#  301: 'wrecked',
#  302: 'county',
#  303: 'tornado',
#  304: 'kid',
#  305: 'ill',
#  306: 'ok',
#  307: 'away',
#  308: 'start',
#  309: 'group',
#  310: 'put',
#  311: 'word',
#  312: 'rescuer',
#  313: 'drought',
#  314: 'catastrophe',
#  315: 'rescued',
#  316: 'wound',
#  317: 'dust',
#  318: 'twister',
#  319: 'officer',
#  320: 'suspect',
#  321: 'thought',
#  322: 'red',
#  323: 'armageddon',
#  324: 'violent',
#  325: 'white',
#  326: 'real',
#  327: 'terrorism',
#  328: 'battle',
#  329: 'land',
#  330: 'boat',
#  331: 'collapsed',
#  332: 'cliff',
#  333: 'curfew',
#  334: 'danger',
#  335: 'hundred',
#  336: 'deluge',
#  337: 'stock',
#  338: 'investigator',
#  339: 'massacre',
#  340: 'mudslide',
#  341: 'structural',
#  342: 'sandstorm',
#  343: 'whirlwind',
#  344: 'better',
#  345: 'least',
#  346: 'came',
#  347: 'airplane',
#  348: 'crashed',
#  349: 'national',
#  350: 'august',
#  351: 'saw',
#  352: 'x',
#  353: 'tragedy',
#  354: 'rioting',
#  355: 'crush',
#  356: 'drowning',
#  357: 'engulfed',
#  358: 'screamed',
#  359: 'quarantine',
#  360: 'quarantined',
#  361: 'sunk',
#  362: 'order',
#  363: 'second',
#  364: 'horrible',
#  365: 'past',
#  366: 'heard',
#  367: 'plane',
#  368: 'iran',
#  369: 'apocalypse',
#  370: 'mosque',
#  371: 'wan',
#  372: 'oh',
#  373: 'bleeding',
#  374: 'effect',
#  375: 'anniversary',
#  376: 'bombed',
#  377: 'hazard',
#  378: 'displaced',
#  379: 'traumatised',
#  380: 'hazardous',
#  381: 'china',
#  382: 'collision',
#  383: 'derail',
#  384: 'devastation',
#  385: 'exploded',
#  386: 'inundated',
#  387: 'scream',
#  388: 'windstorm',
#  389: 'tomorrow',
#  390: 'twitter',
#  391: 'blast',
#  392: 'song',
#  393: 'power',
#  394: 'fedex',
#  395: 'pic',
#  396: 'blew',
#  397: 'blown',
#  398: 'chemical',
#  399: 'desolation',
#  400: 'electrocuted',
#  401: 'famine',
#  402: 'bang',
#  403: 'lava',
#  404: 'book',
#  405: 'reunion',
#  406: 'government',
#  407: 'ebay',
#  408: 'fight',
#  409: 'must',
#  410: 'went',
#  411: 'id',
#  412: 'long',
#  413: 'shoulder',
#  414: 'person',
#  415: 'calgary',
#  416: 'bioterror',
#  417: 'lady',
#  418: 'drown',
#  419: 'half',
#  420: 'catastrophic',
#  421: 'affected',
#  422: 'responder',
#  423: 'collide',
#  424: 'isi',
#  425: 'derailed',
#  426: 'trouble',
#  427: 'detonate',
#  428: 'evacuated',
#  429: 'flattened',
#  430: 'panicking',
#  431: 'street',
#  432: 'cool',
#  433: 'something',
#  434: 'thank',
#  435: 'left',
#  436: 'meltdown',
#  437: 'possible',
#  438: 'ship',
#  439: 'river',
#  440: 'v',
#  441: 'zone',
#  442: 'soon',
#  443: 'stay',
#  444: 'send',
#  445: 'murderer',
#  446: 'volcano',
#  447: 'typhoon',
#  448: 'demolish',
#  449: 'hijacker',
#  450: 'hijacking',
#  451: 'razed',
#  452: 'reason',
#  453: 'place',
#  454: 'due',
#  455: 'care',
#  456: 'traffic',
#  457: 'use',
#  458: 'n',
#  459: 'didnt',
#  460: 'men',
#  461: 'airport',
#  462: 'annihilated',
#  463: 'case',
#  464: 'american',
#  465: 'india',
#  466: 'medium',
#  467: 'deal',
#  468: 'sure',
#  469: 'longer',
#  470: 'security',
#  471: 'ur',
#  472: 'bagging',
#  473: 'pkk',
#  474: 'caused',
#  475: 'crushed',
#  476: 'detonation',
#  477: 'tsunami',
#  478: 'obliterated',
#  479: 'pandemonium',
#  480: 'detonated',
#  481: 'site',
#  482: 'thanks',
#  483: 'used',
#  484: 'rd',
#  485: 'tell',
#  486: 'shooting',
#  487: 'b',
#  488: 'arson',
#  489: 'yet',
#  490: 'music',
#  491: 'beautiful',
#  492: 'lab',
#  493: 'blazing',
#  494: 'nothing',
#  495: 'find',
#  496: 'memory',
#  497: 'demolished',
#  498: 'demolition',
#  499: 'drowned',
#  500: 'eyewitness',
#  501: 'prebreak',
#  502: 'obliterate',
#  503: 'obliteration',
#  504: 'la',
#  505: 'three',
#  506: 'whats',
#  507: 'inside',
#  508: 'already',
#  509: 'making',
#  510: 'done',
#  511: 'play',
#  512: 'dog',
#  513: 'nigga',
#  514: 'country',
#  515: 'horror',
#  516: 'fun',
#  517: 'remember',
#  518: 'policy',
#  519: 'bush',
#  520: 'rise',
#  521: 'cyclone',
#  522: 'abc',
#  523: 'hellfire',
#  524: 'upheaval',
#  525: 'died',
#  526: 'far',
#  527: 'wait',
#  528: 'ablaze',
#  529: 'leave',
#  530: 'mean',
#  531: 'actually',
#  532: 'believe',
#  533: 'wake',
#  534: 'bc',
#  535: 'move',
#  536: 'gun',
#  537: 'israeli',
#  538: 'team',
#  539: 'crew',
#  540: 'turkey',
#  541: 'electrocute',
#  542: 'hijack',
#  543: 'sue',
#  544: 'rainstorm',
#  545: 'south',
#  546: 'north',
#  547: 'support',
#  548: 'p',
#  549: 'win',
#  550: 'brown',
#  551: 'victim',
#  552: 'helicopter',
#  553: 'bar',
#  554: 'hell',
#  555: 'trying',
#  556: 'feeling',
#  557: 'doesnt',
#  558: 'action',
#  559: 'yes',
#  560: 'computer',
#  561: 're\x89û',
#  562: 'line',
#  563: 'nearby',
#  564: 'mp',
#  565: 'declares',
#  566: 'seismic',
#  567: 'yearold',
#  568: 'reactor',
#  569: '\x89ûó',
#  570: 'r',
#  571: 'month',
#  572: 'nowplaying',
#  573: 'ago',
#  574: 'wont',
#  575: 'history',
#  576: 'anything',
#  577: 'avalanche',
#  578: 'star',
#  579: 'health',
#  580: 'c',
#  581: 'level',
#  582: 'km',
#  583: 'tree',
#  584: 'deluged',
#  585: 'islam',
#  586: 'rubble',
#  587: 'swallowed',
#  588: 'snowstorm',
#  589: 'flag',
#  590: 'side',
#  591: 'outside',
#  592: 'west',
#  593: 'k',
#  594: 'center',
#  595: 'stand',
#  596: 'almost',
#  597: 'aircraft',
#  598: 'maybe',
#  599: 'peace',
#  600: 'data',
#  601: 'rule',
#  602: 'yeah',
#  603: 'blight',
#  604: 'watching',
#  605: 'handbag',
#  606: 'bigger',
#  607: 'typhoondevastated',
#  608: 'saipan',
#  609: 'stretcher',
#  610: 'conclusively',
#  611: 'secret',
#  612: 'america',
#  613: 'vehicle',
#  614: 'moment',
#  615: 'die',
#  616: 'anyone',
#  617: 'reuters',
#  618: 'hey',
#  619: 'name',
#  620: 'hand',
#  621: 'point',
#  622: 'christian',
#  623: 'gt',
#  624: 'pick',
#  625: 'literally',
#  626: 'tweet',
#  627: 'transport',
#  628: 'bioterrorism',
#  629: 'searching',
#  630: 'low',
#  631: 'money',
#  632: 'spot',
#  633: 'aug',
#  634: 'hear',
#  635: 'projected',
#  636: 'bestnaijamade',
#  637: 'lost',
#  638: 'thousand',
#  639: 'happy',
#  640: 'mom',
#  641: 'finally',
#  642: 'theyre',
#  643: 'might',
#  644: 'couple',
#  645: 'everything',
#  646: 'ball',
#  647: 'share',
#  648: 'tv',
#  649: 'amid',
#  650: 'town',
#  651: 'blaze',
#  652: 'lie',
#  653: 'hollywood',
#  654: 'pretty',
#  655: 'firefighter',
#  656: 'online',
#  657: 'cake',
#  658: 'rock',
#  659: 'probably',
#  660: 'village',
#  661: 'saved',
#  662: 'soudelor',
#  663: 'manslaughter',
#  664: 'fast',
#  665: 'try',
#  666: 'talk',
#  667: 'expert',
#  668: 'shes',
#  669: 'feared',
#  670: 'pakistan',
#  671: 'seen',
#  672: 'annihilation',
#  673: 'human',
#  674: 'major',
#  675: 'class',
#  676: 'crisis',
#  677: 'leather',
#  678: 'caught',
#  679: 'million',
#  680: 'muslim',
#  681: 'okay',
#  682: 'damn',
#  683: 'youth',
#  684: 'space',
#  685: 'problem',
#  686: 'open',
#  687: 'pay',
#  688: 'though',
#  689: 'link',
#  690: 'coach',
#  691: 'mark',
#  692: 'giant',
#  693: 'course',
#  694: 'chance',
#  695: 'desolate',
#  696: 'trench',
#  697: 'hat',
#  698: 'refugio',
#  699: 'costlier',
#  700: 'miner',
#  701: 'flash',
#  702: 'others',
#  703: 'huge',
#  704: 'drive',
#  705: 'daily',
#  706: 'wrong',
#  707: 'omg',
#  708: 'crazy',
#  709: 'hate',
#  710: 'self',
#  711: 'film',
#  712: 'called',
#  713: 'isnt',
#  714: 'blue',
#  715: 'control',
#  716: 'claim',
#  717: 'texas',
#  718: 'force',
#  719: 'nearly',
#  720: 'seek',
#  721: 'turn',
#  722: 'idea',
#  723: 'morning',
#  724: 'russian',
#  725: 'gbbo',
#  726: 'banned',
#  727: 'knock',
#  728: 'utc',
#  729: 'picking',
#  730: 'mayhem',
#  731: 'offensive',
#  732: 'closed',
#  733: 'heavy',
#  734: 'across',
#  735: 'haha',
#  736: 'sky',
#  737: 'lord',
#  738: 'hard',
#  739: 'aftershock',
#  740: 'sorry',
#  741: 'usa',
#  742: 'poor',
#  743: 'radio',
#  744: 'toddler',
#  745: 'united',
#  746: 'east',
#  747: 'militant',
#  748: 'worst',
#  749: 'view',
#  750: 'favorite',
#  751: 'listen',
#  752: 'anthrax',
#  753: 'mishap',
#  754: 'gem',
#  755: 'entire',
#  756: 'meek',
#  757: 'alarm',
#  758: 'camp',
#  759: 'mph',
#  760: 'become',
#  761: 'company',
#  762: 'angry',
#  763: 'ignition',
#  764: 'nw',
#  765: 'hailstorm',
#  766: 'myanmar',
#  767: 'alone',
#  768: 'arsonist',
#  769: 'climate',
#  770: 'happened',
#  771: 'member',
#  772: 'number',
#  773: 'driver',
#  774: 'soul',
#  775: 'totally',
#  776: 'give',
#  777: 'lead',
#  778: 'hero',
#  779: 'date',
#  780: 'learn',
#  781: 'truth',
#  782: 'burn',
#  783: 'beach',
#  784: 'act',
#  785: 'temple',
#  786: 'mount',
#  787: 'fukushima',
#  788: 'taken',
#  789: 'playing',
#  790: 'australia',
#  791: 'public',
#  792: 'running',
#  793: 'looking',
#  794: 'foot',
#  795: 'pain',
#  796: 'blizzard',
#  797: 'wow',
#  798: 'drake',
#  799: 'appears',
#  800: 'thursday',
#  801: 'centre',
#  802: 'bbc',
#  803: 'issued',
#  804: 'emmerdale',
#  805: 'flight',
#  806: 'passenger',
#  807: 'declaration',
#  808: 'disea',
#  809: 'spring',
#  810: 'cry',
#  811: 'wanted',
#  812: 'front',
#  813: 'student',
#  814: 'else',
#  815: 'risk',
#  816: 'property',
#  817: 'comment',
#  818: 'global',
#  819: 'begin',
#  820: 'cop',
#  821: 'trust',
#  822: 'ready',
#  823: 'park',
#  824: 'horse',
#  825: 'till',
#  826: 'track',
#  827: 'green',
#  828: 'civilian',
#  829: 'miss',
#  830: 'germ',
#  831: 'mad',
#  832: 'party',
#  833: 'dude',
#  834: 'follow',
#  835: 'aint',
#  836: 'release',
#  837: 'art',
#  838: 'break',
#  839: 'large',
#  840: 'downtown',
#  841: 'insurance',
#  842: 'instead',
#  843: 'wonder',
#  844: 'quiz',
#  845: 'cnn',
#  846: 'devastated',
#  847: 'reddits',
#  848: 'virgin',
#  849: 'chile',
#  850: 'bring',
#  851: 'season',
#  852: 'taking',
#  853: 'scene',
#  854: 'behind',
#  855: 'four',
#  856: 'israel',
#  857: 'following',
#  858: 'disease',
#  859: 'mountain',
#  860: 'scared',
#  861: 'escape',
#  862: 'govt',
#  863: 'mop',
#  864: 'ca',
#  865: 'hiring',
#  866: 'true',
#  867: 'theater',
#  868: 'gave',
#  869: 'gop',
#  870: 'king',
#  871: 'piece',
#  872: 'cover',
#  873: 'driving',
#  874: 'nd',
#  875: 'added',
#  876: 'strike',
#  877: 'tote',
#  878: 'room',
#  879: 'libya',
#  880: 'nagasaki',
#  881: 'outrage',
#  882: 'ppl',
#  883: 'british',
#  884: 'animal',
#  885: 'landing',
#  886: 'download',
#  887: 'york',
#  888: 'patience',
#  889: 'former',
#  890: 'madhya',
#  891: 'pradesh',
#  892: 'nigerian',
#  893: 'led',
#  894: 'lamp',
#  895: 'funtenna',
#  896: 'ancient',
#  897: 'subreddits',
#  898: 'lake',
#  899: 'colorado',
#  900: 'london',
#  901: 'awesome',
#  902: 'upon',
#  903: 'reported',
#  904: 'owner',
#  905: 'turned',
#  906: 'dance',
#  907: 'seeing',
#  908: 'thinking',
#  909: 'france',
#  910: 'wednesday',
#  911: 'mode',
#  912: 'g',
#  913: 'early',
#  914: 'pakistani',
#  915: 'em',
#  916: 'potus',
#  917: 'bed',
#  918: 'series',
#  919: 'department',
#  920: 'earth',
#  921: 'working',
#  922: 'russia',
#  923: 'lmao',
#  924: 'shift',
#  925: 'pamela',
#  926: 'answer',
#  927: 'lt',
#  928: 'cut',
#  929: 'ebola',
#  930: 'threat',
#  931: 'event',
#  932: 'enough',
#  933: 'told',
#  934: 'info',
#  935: 'biggest',
#  936: 'wall',
#  937: 'fashion',
#  938: 'middle',
#  939: 'gunman',
#  940: 'pray',
#  941: 'holding',
#  942: 'likely',
#  943: 'brother',
#  944: 'desire',
#  945: 'image',
#  946: 'uk',
#  947: 'sea',
#  948: 'cat',
#  949: 'cost',
#  950: 'bayelsa',
#  951: 'parole',
#  952: 'unconfirmed',
#  953: 'neighbour',
#  954: 'rly',
#  955: 'galactic',
#  956: 'expected',
#  957: 'direction',
#  958: 'ave',
#  959: 'teen',
#  960: 'mile',
#  961: 'guess',
#  962: 'tried',
#  963: 'career',
#  964: 'safety',
#  965: 'fact',
#  966: 'wasnt',
#  967: 'started',
#  968: 'question',
#  969: 'dad',
#  970: 'door',
#  971: 'sport',
#  972: 'japanese',
#  973: 'palestinian',
#  974: 'arrested',
#  975: 'capture',
#  976: 'terror',
#  977: 'worry',
#  978: 'waving',
#  979: 'geller',
#  980: 'unit',
#  981: 'album',
#  982: 'playlist',
#  983: 'young',
#  984: 'research',
#  985: 'ahead',
#  986: 'test',
#  987: 'bitch',
#  988: 'result',
#  989: 'article',
#  990: 'super',
#  991: 'investigating',
#  992: 'washington',
#  993: 'coast',
#  994: 'ground',
#  995: 'worse',
#  996: 'ash',
#  997: 'parent',
#  998: 'sex',
#  999: 'account',
#  1000: 'sad',
#  ...}

# %%
encoded_text = token.texts_to_sequences(text)
X_train_encoded = encoded_text

# %% [markdown]
# Max length

# %%
 def find_max_len(lst):
    """
    Python3 program to Find maximum length list in a nested list
    """
    maxList = max(lst, key = len)
    maxLength = max(map(len, lst))
      
    return maxList, maxLength

print(find_max_len(encoded_text))
# Out:
# ([8416, 44, 8417, 8418, 8419, 333, 412, 590, 1747, 2813, 4745, 3200, 1821, 160, 8420, 8421, 1821, 267, 3416, 4745, 8422, 204, 490], 23)

# %%
max_length = 23 #modifier par le nombre max de mots dans le dataset

# %% [markdown]
# ### Word2vec Vectors

# %%
# !pip install gensim python-Levenshtein
import gensim.downloader as api
# Out:
# Requirement already satisfied: gensim in /home/dianavo/.pyenv/versions/3.8.12/envs/nlp_project/lib/python3.8/site-packages (4.1.2)
# Requirement already satisfied: python-Levenshtein in /home/dianavo/.pyenv/versions/3.8.12/envs/nlp_project/lib/python3.8/site-packages (0.12.2)
# Requirement already satisfied: scipy>=0.18.1 in /home/dianavo/.pyenv/versions/3.8.12/envs/nlp_project/lib/python3.8/site-packages (from gensim) (1.8.0)
# Requirement already satisfied: numpy>=1.17.0 in /home/dianavo/.pyenv/versions/3.8.12/envs/nlp_project/lib/python3.8/site-packages (from gensim) (1.22.3)
# Requirement already satisfied: smart-open>=1.8.1 in /home/dianavo/.pyenv/versions/3.8.12/envs/nlp_project/lib/python3.8/site-packages (from gensim) (5.2.1)
# Requirement already satisfied: setuptools in /home/dianavo/.pyenv/versions/3.8.12/envs/nlp_project/lib/python3.8/site-packages (from python-Levenshtein) (61.3.1)

# %%
# load a word2vec embedding
word2vec_transfer = api.load("glove-wiki-gigaword-50")

def embed_sentence_with_TF(word2vec, sentence):
    """convert a sentence (list of words) into a matrix representing the words in the embedding space"""
    embedded_sentence = []
    for word in sentence:
        if word in word2vec:
            embedded_sentence.append(word2vec[word])
        
    return np.array(embedded_sentence)



def embedding(word2vec, sentences):
    """converts a list of sentences into a list of matrices"""
    embed = []
    
    for sentence in sentences:
        embedded_sentence = embed_sentence_with_TF(word2vec, sentence)
        embed.append(embedded_sentence)
        
    return embed

# Embed the training and test sentences
X_train_embed_2 = embedding(word2vec_transfer, X_train_encoded)
X_test_embed_2 = embedding(word2vec_transfer, X_test)

# Pad the training and test embedded sentences , use in 'weights'
X_train_pad_2 = pad_sequences(X_train_embed_2, dtype='float32', padding='post', maxlen=25)
X_test_pad_2 = pad_sequences(X_test_embed_2, dtype='float32', padding='post', maxlen=25)

# %%
X_train_pad_2.shape
# X.shape = (n_sentences, max_sentence_length, embedding_dim)
# Out:
# (7613, 25, 50)

# %% [markdown]
# ### TF2.0 and Keras Model Building

# %%
# included in model.fit() X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size= 0.2, stratify = y)
maxlen = 25  # new vec_size 
embedding_dim = 50

# %% [markdown]
# ### CNN

# %%
# TEST #

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# compile the model
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc',f1_m,precision_m, recall_m])

# %%
# keras metric precision :
precision = tf.keras.metrics.Precision(thresholds=None, top_k=None, class_id=None, name=None, dtype=None)

# %% [markdown]
# ### Model RNN

# %%
def model_init():
    model = Sequential()
    model.add(layers.Masking())
    model.add(layers.LSTM(10, return_sequences=True))
    model.add(layers.LSTM(10))
    model.add(layers.Dense(30, activation='relu'))
    model.add(layers.Dropout(0.15))
    model.add(layers.Dense(1, activation='sigmoid'))

    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy', precision])
    
    return model

# %%
model2 = model_init()

# %%
#  restore_best_weights=True

# %%
es = EarlyStopping(patience=5)

history = model2.fit(X_train_pad_2, y_train, 
          batch_size = 16,
          epochs=400,
          validation_split=0.3,
          callbacks=[es]
         )
# Out:
# Epoch 1/400
# 334/334 [==============================] - 102s 227ms/step - loss: 0.6816 - accuracy: 0.5712 - precision_m: 0.1460 - val_loss: 0.6770 - val_accuracy: 0.5622 - val_precision_m: 0.2701
# Epoch 2/400
# 334/334 [==============================] - 67s 202ms/step - loss: 0.6562 - accuracy: 0.6234 - precision_m: 0.5899 - val_loss: 0.6747 - val_accuracy: 0.5841 - val_precision_m: 0.3821
# Epoch 3/400
# 334/334 [==============================] - 67s 201ms/step - loss: 0.6325 - accuracy: 0.6525 - precision_m: 0.6473 - val_loss: 0.6583 - val_accuracy: 0.6257 - val_precision_m: 0.4927
# Epoch 4/400
# 334/334 [==============================] - 67s 202ms/step - loss: 0.6119 - accuracy: 0.6712 - precision_m: 0.6569 - val_loss: 0.6539 - val_accuracy: 0.6274 - val_precision_m: 0.4913
# Epoch 5/400
# 334/334 [==============================] - 76s 229ms/step - loss: 0.5903 - accuracy: 0.6900 - precision_m: 0.7055 - val_loss: 0.6537 - val_accuracy: 0.6309 - val_precision_m: 0.5115
# Epoch 6/400
# 334/334 [==============================] - 77s 231ms/step - loss: 0.5744 - accuracy: 0.7088 - precision_m: 0.7145 - val_loss: 0.6931 - val_accuracy: 0.6195 - val_precision_m: 0.4030
# Epoch 7/400
# 334/334 [==============================] - 78s 232ms/step - loss: 0.5557 - accuracy: 0.7262 - precision_m: 0.7572 - val_loss: 0.6726 - val_accuracy: 0.6274 - val_precision_m: 0.5049
# Epoch 8/400
# 334/334 [==============================] - 78s 234ms/step - loss: 0.5379 - accuracy: 0.7343 - precision_m: 0.7450 - val_loss: 0.6885 - val_accuracy: 0.6222 - val_precision_m: 0.4161
# Epoch 9/400
# 334/334 [==============================] - 81s 243ms/step - loss: 0.5204 - accuracy: 0.7446 - precision_m: 0.7698 - val_loss: 0.6767 - val_accuracy: 0.6370 - val_precision_m: 0.4802
# Epoch 10/400
# 334/334 [==============================] - 69s 208ms/step - loss: 0.5077 - accuracy: 0.7589 - precision_m: 0.7758 - val_loss: 0.6868 - val_accuracy: 0.6099 - val_precision_m: 0.4823

# %% [markdown]
# > F1 : F1 Score might be a better measure to use if we need to seek a balance between Precision and Recall AND there is an uneven class distribution (large number of Actual Negatives).

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
test_loss, test_acc = model_cnn.evaluate(X_test) # test.csv
print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)

# %%
# print("Test Loss", history[0])
# print("Test Accuracy", history[1])

# %% [markdown]
# ## Test on Camille's model

# %% [markdown]
# Prediction👌😍

# %%
y_new = model_cnn.predict(X_test)
